# %% [markdown]
# # Marginal and Conditional Distrubution

# %% [markdown]
# This project aims to apply the statistics concept of marginal and conditional distribution to a student performance dataset.

# %% [markdown]
# ## Setup and libraries

# %% [markdown]
# Importing the neccessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Overview

# %%
import pandas as pd

df = pd.read_csv("StudentPerformanceFactors.csv")
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# The following categories have missing values:
# - Teacher Quality
# - Parental Education Level
# - Distance from home
#
# We need to see how often these missing values occur and also visualize it

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Visualize missingness
msno.matrix(df)
plt.show()

# %%
print (df.isnull().sum())
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# Percentage of missing values:
# - Teacher quality: **1.18**
# - Parental Education level: **1.36**
# - Distance from home: **1.01**
#
# Since the percentage is low we can fill the missing values with the mode

# %%
import pandas as pd

df['Teacher_Quality'] = df['Teacher_Quality'].fillna(mode_value)
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(mode_value)
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(mode_value)
print (df.isnull().sum())
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# ## Marginal Distribution of each category

# %% [markdown]
# ### Hours Studied

# %%
#Histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['Hours_Studied'], bins=10, color= 'green')
plt.title('Distribution of Study Hours')
plt.xlabel('Hours Studied Per Week')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# ### Attendance

# %%
#Histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['Attendance'], bins=10)
plt.title('Distribution of Attendance')
plt.xlabel('Percentage of Class Attendance')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# ### Parental Involement

# %%
#Bar Plot
sns.countplot(x='Parental_Involvement', data=df)
plt.title('Distribution of Parental Involvement')
plt.xlabel('Parental Involvement')
plt.ylabel('Number of Students')
plt.show()

# %%
#Bar plot
sns.countplot(data=df, x='Access_to_Resources')

plt.title('Distribution of Access to Resources')
plt.xlabel('Access to resources?(yes or no)')
plt.ylabel('Number of Students')
plt.show()

# %%
#Bar plot
sns.countplot(data=df, x='Extracurricular_Activities')

plt.title('Distribution of Extracurricular Activities')
plt.xlabel('Extracurricular? Yes or No')
plt.ylabel('Number of Students')
plt.show()
